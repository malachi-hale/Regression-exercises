# %% [markdown]
# # Mall Customer Exploration Exercises

# %%
#Disable warnings
import warnings
warnings.filterwarnings("ignore")

#General libraries needed
import pandas as pd
import numpy as np

#Libraries for graphing
import matplotlib.pyplot as plt
import seaborn as sns

#Train, test, split
from sklearn.model_selection import train_test_split

#Library for statistical testing
from scipy import stats

#Imports for Telco Data
from explore import get_mall_customer_data

#Imports for Exploring Data
from explore import plot_variable_pairs
from explore import plot_categorical_and_continuous_vars

# %% [markdown]
# ## Acquire Data

# %%
df = get_mall_customer_data()

# %%
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %% [markdown]
# ## Plot Variable Pairs

# %%
plot_variable_pairs(df)

# %% [markdown]
# ## Plot Categorical and Continuous Variables

# %%
categorical_mall= ["gender", "age"]
continuous_mall = ["annual_income", "spending_score"]
plot_categorical_and_continuous_vars(df, categorical_mall, continuous_mall)
# Out:
# (<AxesSubplot:xlabel='age', ylabel='spending_score'>,
#  <AxesSubplot:xlabel='age', ylabel='spending_score'>,
#  <AxesSubplot:xlabel='age', ylabel='spending_score'>)
